# %%
import pandas
import matplotlib.pyplot as plt
european_countries_companies = pandas.read_csv('european_countries_companies.csv')
european_countries_companies.plot(x='Country',y='Companies Count',kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Country'>
